# %%
import csv
import json
import pandas as pd

# %%
related_matches = pd.read_csv('related_matches.csv')

# %%
related_matches
# Out:
#     label_uri         literal lang  \
# 0        l_01      Aboriginal   en
# 1        l_07      Allochtoon   en
# 2       l_100           Baboo   en
# 3        l_10       Barbarian   en
# 4        l_21         Batavia   en
# ..        ...             ...  ...
# 153     l_282         Westers   nl
# 154     l_200             Wit   nl
# 155     l_283        Zigeuner   nl
# 156     l_169  Zuid­-Rhodesië   nl
# 157     l_199           Zwart   nl
#
#                                            query_terms        aat  wikidata  \
# 0                               aboriginal#aboriginals  300379660   Q103817
# 1                               allochtoon#allochtoons       None  Q2008347
# 2                                         baboo#baboos       None      None
# 3                                 barbarian#barbarians       None   Q134313
# 4                                     batavia#batavias       None  Q1199713
# ..                                                 ...        ...       ...
# 153  westers#wester#westerse#westersere#westerste#w...       None   Q160381
# 154  wit#witten#wittere#witst#witte#witter#wits#witste       None   Q235155
# 155                                 zigeuner#zigeuners  300404070    Q76475
# 156                                      zuid-rhodesië       None   Q750583
# 157  zwart#zwarten#zwartst#zwarter#zwarts#zwarte#zw...       None   Q817393
#
#                                          pwn                   odwn      nmvw
# 0                    native.n.01#native.a.03                   None      None
# 1                                       None                   None      None
# 2                                       None                   None      None
# 3    savage.n.01#peasant.n.03#barbarian.s.01                   None      None
# 4                                       None                   None      None
# ..                                       ...                    ...       ...
# 153                                     None                   None      None
# 154                                     None                   None      None
# 155                                     None           zigeuner-n-1  10075876
# 156                                     None                   None      None
# 157                                     None  zwarte-n-1#zwarte-n-3      None
#
# [158 rows x 9 columns]

# %%
# generating a dict
related_matches_dict = {}

for row in related_matches.iterrows():
    
    rm_per_label = {'aat':[row[1].aat],
                    'wikidata':[row[1].wikidata],
                    'pwn':row[1].pwn.split('#'),
                    'odwn':row[1].odwn.split('#'),
                    'nmvw':[row[1].nmvw]}
    
    related_matches_dict[row[1].label_uri] = {'literal_form':row[1].literal,
                                             'lang':row[1].lang,
                                             'query_terms':row[1].query_terms.split('#'),
                                             'related_matches':rm_per_label}

# %%
related_matches_dict
# Out:
# {'l_01': {'literal_form': 'Aboriginal',
#   'lang': 'en',
#   'query_terms': ['aboriginal', 'aboriginals'],
#   'related_matches': {'aat': ['300379660'],
#    'wikidata': ['Q103817'],
#    'pwn': ['native.n.01', 'native.a.03'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_07': {'literal_form': 'Allochtoon',
#   'lang': 'en',
#   'query_terms': ['allochtoon', 'allochtoons'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q2008347'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_100': {'literal_form': 'Baboo',
#   'lang': 'en',
#   'query_terms': ['baboo', 'baboos'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_10': {'literal_form': 'Barbarian',
#   'lang': 'en',
#   'query_terms': ['barbarian', 'barbarians'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q134313'],
#    'pwn': ['savage.n.01', 'peasant.n.03', 'barbarian.s.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_21': {'literal_form': 'Batavia',
#   'lang': 'en',
#   'query_terms': ['batavia', 'batavias'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1199713'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_11': {'literal_form': 'Berber',
#   'lang': 'en',
#   'query_terms': ['berber', 'berbers'],
#   'related_matches': {'aat': ['300016593'],
#    'wikidata': ['Q45315'],
#    'pwn': ['berber.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_14': {'literal_form': 'Black',
#   'lang': 'en',
#   'query_terms': ['black', 'blacks', 'blackest', 'blacker'],
#   'related_matches': {'aat': ['300435249'],
#    'wikidata': ['Q817393'],
#    'pwn': ['black.n.05', 'black.a.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_17': {'literal_form': 'Bombay',
#   'lang': 'en',
#   'query_terms': ['bombay', 'bombays'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1156'],
#    'pwn': ['mumbai.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_22': {'literal_form': 'Burma',
#   'lang': 'en',
#   'query_terms': ['burma'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q836'],
#    'pwn': ['myanmar.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_24': {'literal_form': 'Bush Negro',
#   'lang': 'en',
#   'query_terms': ['bush negro', 'bush negros', 'bush negroes'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_19': {'literal_form': 'Calcutta',
#   'lang': 'en',
#   'query_terms': ['calcutta', 'calcuttas'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1348'],
#    'pwn': ['kolkata.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_26': {'literal_form': 'Caucasian',
#   'lang': 'en',
#   'query_terms': ['caucasian', 'caucasians'],
#   'related_matches': {'aat': ['300244536'],
#    'wikidata': ['Q7129609'],
#    'pwn': ['white.n.01', 'caucasian.s.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_27': {'literal_form': 'Colored',
#   'lang': 'en',
#   'query_terms': ['colored', 'coloreds'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q5149038'],
#    'pwn': ['colored.s.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_32': {'literal_form': 'Coolie',
#   'lang': 'en',
#   'query_terms': ['coolie', 'coolies'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q548135'],
#    'pwn': ['coolie.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_33': {'literal_form': 'Descent',
#   'lang': 'en',
#   'query_terms': ['descent'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q89659343'],
#    'pwn': ['origin.n.02', 'descent.n.04', 'lineage.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_107': {'literal_form': 'Developing nations',
#   'lang': 'en',
#   'query_terms': ['developing nations', 'developing nation'],
#   'related_matches': {'aat': ['300379994'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_34': {'literal_form': 'Disabled',
#   'lang': 'en',
#   'query_terms': ['disabled', 'disableds'],
#   'related_matches': {'aat': ['300025921'],
#    'wikidata': ['Q15978181'],
#    'pwn': ['disabled.n.01', 'disable.v.02', 'disabled.s.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_38': {'literal_form': 'Discover',
#   'lang': 'en',
#   'query_terms': ['discover'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['discover.v.07'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_39': {'literal_form': 'Dwarf',
#   'lang': 'en',
#   'query_terms': ['dwarf', 'dwarves', 'dwarfs', 'dwarfer', 'dwarfest'],
#   'related_matches': {'aat': ['300236748'],
#    'wikidata': ['None'],
#    'pwn': ['dwarf.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_43': {'literal_form': 'Eskimo',
#   'lang': 'en',
#   'query_terms': ['eskimo', 'eskimoes', 'eskimos'],
#   'related_matches': {'aat': ['300017447'],
#    'wikidata': ['Q131242'],
#    'pwn': ['eskimo.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_45': {'literal_form': 'ethnic groups',
#   'lang': 'en',
#   'query_terms': ['ethnic groups', 'ethnic group'],
#   'related_matches': {'aat': ['300191997'],
#    'wikidata': ['Q41710'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_44': {'literal_form': 'Ethnicity',
#   'lang': 'en',
#   'query_terms': ['ethnicity', 'ethnicities'],
#   'related_matches': {'aat': ['300250435'],
#    'wikidata': ['Q5404323'],
#    'pwn': ['ethnicity.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_46': {'literal_form': 'Exotic',
#   'lang': 'en',
#   'query_terms': ['exotic', 'exotics'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['alien.s.02', 'exotic.s.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_105': {'literal_form': 'First World',
#   'lang': 'en',
#   'query_terms': ['first world'],
#   'related_matches': {'aat': ['300449024'],
#    'wikidata': ['Q876830'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_99': {'literal_form': 'Footmen',
#   'lang': 'en',
#   'query_terms': ['footmen', 'footman'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q4382663'],
#    'pwn': ['footman.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_51': {'literal_form': 'full blood',
#   'lang': 'en',
#   'query_terms': ['full blood'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_47': {'literal_form': 'Gay',
#   'lang': 'en',
#   'query_terms': ['gay', 'gayer', 'gayest', 'gays'],
#   'related_matches': {'aat': ['300055188'],
#    'wikidata': ['Q592'],
#    'pwn': ['homosexual.n.01', 'gay.s.06'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_48': {'literal_form': 'Gypsy',
#   'lang': 'en',
#   'query_terms': ['gypsy', 'gypsys', 'gypsies'],
#   'related_matches': {'aat': ['300404070'],
#    'wikidata': ['Q8060'],
#    'pwn': ['gypsy.n.02', 'gypsy.n.03'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_50': {'literal_form': 'Half-blood',
#   'lang': 'en',
#   'query_terms': ['half-blood', 'half-bloods'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_52': {'literal_form': 'half-breed',
#   'lang': 'en',
#   'query_terms': ['half-breed', 'half-breeds'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q17144151'],
#    'pwn': ['half-breed.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_119': {'literal_form': 'Handicap',
#   'lang': 'en',
#   'query_terms': ['handicap', 'handicaps'],
#   'related_matches': {'aat': ['300025921'],
#    'wikidata': ['Q12131'],
#    'pwn': ['disability.n.01', 'disable.v.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_56': {'literal_form': 'Headhunter',
#   'lang': 'en',
#   'query_terms': ['headhunter', 'headhunters'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['headhunter.n.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_57': {'literal_form': 'Hermaphrodite',
#   'lang': 'en',
#   'query_terms': ['hermaphrodite', 'hermaphrodites'],
#   'related_matches': {'aat': ['300386060'],
#    'wikidata': ['Q303479'],
#    'pwn': ['hermaphrodite.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_121': {'literal_form': 'homo',
#   'lang': 'en',
#   'query_terms': ['homo', 'homos'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['homosexual.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_59': {'literal_form': 'Homosexual',
#   'lang': 'en',
#   'query_terms': ['homosexual', 'homosexuals'],
#   'related_matches': {'aat': ['300435115'],
#    'wikidata': ['Q592'],
#    'pwn': ['homosexual.n.01', 'homosexual.a.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_60': {'literal_form': 'Hottentot',
#   'lang': 'en',
#   'query_terms': ['hottentot', 'hottentots'],
#   'related_matches': {'aat': ['300016575'],
#    'wikidata': ['Q1631241'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_134': {'literal_form': 'immigrant',
#   'lang': 'en',
#   'query_terms': ['immigrant', 'immigrants'],
#   'related_matches': {'aat': ['300025844'],
#    'wikidata': ['Q12547146'],
#    'pwn': ['immigrant.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_63': {'literal_form': 'Indian',
#   'lang': 'en',
#   'query_terms': ['indian', 'indians'],
#   'related_matches': {'aat': ['300017437'],
#    'wikidata': ['Q49297'],
#    'pwn': ['indian.a.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_64': {'literal_form': 'Indigenous',
#   'lang': 'en',
#   'query_terms': ['indigenous'],
#   'related_matches': {'aat': ['300379660'],
#    'wikidata': ['Q103817'],
#    'pwn': ['autochthonal.s.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_66': {'literal_form': 'Indo',
#   'lang': 'en',
#   'query_terms': ['indo', 'indos'],
#   'related_matches': {'aat': ['300386794'],
#    'wikidata': ['Q475027'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_116': {'literal_form': 'Inuit',
#   'lang': 'en',
#   'query_terms': ['inuit', 'inuits'],
#   'related_matches': {'aat': ['300017455'],
#    'wikidata': ['Q189975'],
#    'pwn': ['eskimo.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_74': {'literal_form': 'Kaffir',
#   'lang': 'en',
#   'query_terms': ['kaffir', 'kaffirs'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1285250'],
#    'pwn': ['kaffir.n.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_120': {'literal_form': 'lilliputian',
#   'lang': 'en',
#   'query_terms': ['lilliputian', 'lilliputians'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q2419953'],
#    'pwn': ['lilliputian.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_108': {'literal_form': 'low-income countries',
#   'lang': 'en',
#   'query_terms': ['low-income countries', 'low-income country'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q25450947'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_20': {'literal_form': 'Madras',
#   'lang': 'en',
#   'query_terms': ['madras'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1352'],
#    'pwn': ['chennai.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_25': {'literal_form': 'Maroon',
#   'lang': 'en',
#   'query_terms': ['maroon', 'maroons'],
#   'related_matches': {'aat': ['300443390'],
#    'wikidata': ['Q445485'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_76': {'literal_form': 'Medicine Man',
#   'lang': 'en',
#   'query_terms': ['medicine man', 'medicine men'],
#   'related_matches': {'aat': ['300218522'],
#    'wikidata': ['Q266750'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_54': {'literal_form': 'mestizo',
#   'lang': 'en',
#   'query_terms': ['mestizo', 'mestizoes', 'mestizos'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q106713'],
#    'pwn': ['mestizo.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_117': {'literal_form': 'Métis',
#   'lang': 'en',
#   'query_terms': ['métis', 'metis'],
#   'related_matches': {'aat': ['300265512'],
#    'wikidata': ['Q262457'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_79': {'literal_form': 'Mohammedan',
#   'lang': 'en',
#   'query_terms': ['mohammedan', 'mohammedans'],
#   'related_matches': {'aat': ['300073715'],
#    'wikidata': ['Q2367463'],
#    'pwn': ['mohammedan.n.01', 'muhammadan.a.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_81': {'literal_form': 'Mongoloid',
#   'lang': 'en',
#   'query_terms': ['mongoloid', 'mongoloids'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q207912'],
#    'pwn': ['mongoloid.n.01',
#     'mongoloid.n.02',
#     'mongoloid.a.01',
#     'mongoloid.a.02',
#     'mongoloid.a.03'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_82': {'literal_form': 'Moor',
#   'lang': 'en',
#   'query_terms': ['moor', 'moors'],
#   'related_matches': {'aat': ['300375152'],
#    'wikidata': ['Q169260'],
#    'pwn': ['moor.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_83': {'literal_form': 'Mulatto',
#   'lang': 'en',
#   'query_terms': ['mulatto', 'mulattoes', 'mulattos'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q191923'],
#    'pwn': ['mulatto.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_84': {'literal_form': 'Native',
#   'lang': 'en',
#   'query_terms': ['native', 'natives'],
#   'related_matches': {'aat': ['300017437'],
#    'wikidata': ['None'],
#    'pwn': ['native.n.01', 'native.n.02', 'native.a.01', 'native.a.03'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_85': {'literal_form': 'Negro',
#   'lang': 'en',
#   'query_terms': ['negro', 'negroes', 'negros'],
#   'related_matches': {'aat': ['300018125'],
#    'wikidata': ['Q1130557'],
#    'pwn': ['black.n.05', 'colored.s.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_86': {'literal_form': 'Oriental',
#   'lang': 'en',
#   'query_terms': ['oriental', 'orientals'],
#   'related_matches': {'aat': ['300018279'],
#    'wikidata': ['None'],
#    'pwn': ['oriental.s.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_98': {'literal_form': 'Page',
#   'lang': 'en',
#   'query_terms': ['page', 'pages'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q855855'],
#    'pwn': ['page.n.04', 'page.n.05'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_90': {'literal_form': 'Primitive',
#   'lang': 'en',
#   'query_terms': ['primitive', 'primitives'],
#   'related_matches': {'aat': ['300056500'],
#    'wikidata': ['Q13165863'],
#    'pwn': ['primitive.n.01', 'crude.s.04', 'primitive.s.03', 'primitive.s.04'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_91': {'literal_form': 'Primitivism',
#   'lang': 'en',
#   'query_terms': ['primitivism'],
#   'related_matches': {'aat': ['300056548'],
#    'wikidata': ['Q848365'],
#    'pwn': ['crudeness.n.01', 'primitivism.n.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_92': {'literal_form': 'Pygmy',
#   'lang': 'en',
#   'query_terms': ['pygmy', 'pygmys'],
#   'related_matches': {'aat': ['300016430'],
#    'wikidata': ['Q171927'],
#    'pwn': ['pygmy.n.01', 'pygmy.n.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_93': {'literal_form': 'Queer',
#   'lang': 'en',
#   'query_terms': ['queer', 'queerest', 'queerer', 'queers'],
#   'related_matches': {'aat': ['300055188'],
#    'wikidata': ['Q51415'],
#    'pwn': ['fagot.n.01', 'gay.s.06'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_95': {'literal_form': 'Race',
#   'lang': 'en',
#   'query_terms': ['race', 'races'],
#   'related_matches': {'aat': ['300256475'],
#    'wikidata': ['Q3254959'],
#    'pwn': ['race.n.03'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_68': {'literal_form': 'retarded',
#   'lang': 'en',
#   'query_terms': ['retarded'],
#   'related_matches': {'aat': ['300025925'],
#    'wikidata': ['Q18394147'],
#    'pwn': ['mentally_retarded.n.01', 'retarded.a.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_96': {'literal_form': 'Roots',
#   'lang': 'en',
#   'query_terms': ['roots'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['ancestor.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_106': {'literal_form': 'Second World',
#   'lang': 'en',
#   'query_terms': ['second world'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q233472'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_97': {'literal_form': 'Servant',
#   'lang': 'en',
#   'query_terms': ['servant', 'servants'],
#   'related_matches': {'aat': ['300025874'],
#    'wikidata': ['Q54128'],
#    'pwn': ['servant.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_101': {'literal_form': 'Slave',
#   'lang': 'en',
#   'query_terms': ['slave', 'slaves'],
#   'related_matches': {'aat': ['300230899'],
#    'wikidata': ['Q12773225'],
#    'pwn': ['slave.n.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_23': {'literal_form': 'Southern Rhodesia',
#   'lang': 'en',
#   'query_terms': ['southern rhodesia'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q750583'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_104': {'literal_form': 'Third World',
#   'lang': 'en',
#   'query_terms': ['third world'],
#   'related_matches': {'aat': ['300379994'],
#    'wikidata': ['Q180194'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_109': {'literal_form': 'Traditional',
#   'lang': 'en',
#   'query_terms': ['traditional', 'traditionals'],
#   'related_matches': {'aat': ['300435679'],
#    'wikidata': ['None'],
#    'pwn': ['traditional.a.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_111': {'literal_form': 'Trans',
#   'lang': 'en',
#   'query_terms': ['trans', 'transs'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q189125'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_112': {'literal_form': 'transvestite',
#   'lang': 'en',
#   'query_terms': ['transvestite', 'transvestites'],
#   'related_matches': {'aat': ['300400510'],
#    'wikidata': ['Q112918934'],
#    'pwn': ['transvestite.n.01', 'transvestic.a.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_114': {'literal_form': 'Tribe',
#   'lang': 'en',
#   'query_terms': ['tribe', 'tribes'],
#   'related_matches': {'aat': ['300049946'],
#    'wikidata': ['Q133311'],
#    'pwn': ['tribe.n.01', 'tribe.n.02', 'kin.n.02'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_115': {'literal_form': 'Western',
#   'lang': 'en',
#   'query_terms': ['western', 'westerns'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q160381'],
#    'pwn': ['western.a.01'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_16': {'literal_form': 'White',
#   'lang': 'en',
#   'query_terms': ['white', 'whiter', 'whitest', 'whites'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q235155'],
#    'pwn': ['white.n.01', 'white.a.02', 'white.s.05'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_142': {'literal_form': 'Aboriginal',
#   'lang': 'nl',
#   'query_terms': ['aboriginal', 'aboriginals'],
#   'related_matches': {'aat': ['300021862'],
#    'wikidata': ['Q170355'],
#    'pwn': ['None'],
#    'odwn': ['aboriginal-n-1'],
#    'nmvw': ['10076668']}},
#  'l_259': {'literal_form': 'achterlijk',
#   'lang': 'nl',
#   'query_terms': ['achterlijk',
#    'achterlijkst',
#    'achterlijkere',
#    'achterlijker',
#    'achterlijke',
#    'achterlijks',
#    'achterlijkste',
#    'achterlijkheid',
#    'achterlijken'],
#   'related_matches': {'aat': ['300025925'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['achterlijkheid-n-1'],
#    'nmvw': ['None']}},
#  'l_149': {'literal_form': 'Afkomst',
#   'lang': 'nl',
#   'query_terms': ['afkomst', 'afkomsten'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1642895'],
#    'pwn': ['None'],
#    'odwn': ['afkomst-n-1', 'afkomst-n-2'],
#    'nmvw': ['None']}},
#  'l_150': {'literal_form': 'Allochtoon',
#   'lang': 'nl',
#   'query_terms': ['allochtoon',
#    'allochtonen',
#    'allochtoons',
#    'allochtoonste',
#    'allochtoonst',
#    'allochtoner',
#    'allochtonere',
#    'allochtone'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q2008347'],
#    'pwn': ['None'],
#    'odwn': ['allochtoon-n-1'],
#    'nmvw': ['None']}},
#  'l_157': {'literal_form': 'baboe',
#   'lang': 'nl',
#   'query_terms': ['baboe', 'baboes'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q936969'],
#    'pwn': ['None'],
#    'odwn': ['baboe-n-1'],
#    'nmvw': ['None']}},
#  'l_153': {'literal_form': 'Barbaar',
#   'lang': 'nl',
#   'query_terms': ['barbaar', 'barbaren'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q134313'],
#    'pwn': ['None'],
#    'odwn': ['barbaar-n-1', 'barbaar-n-3', 'barbaar-n-4'],
#    'nmvw': ['None']}},
#  'l_167': {'literal_form': 'Batavia',
#   'lang': 'nl',
#   'query_terms': ['batavia'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1199713'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['10063182']}},
#  'l_154': {'literal_form': 'Bediende',
#   'lang': 'nl',
#   'query_terms': ['bediende', 'bediendes', 'bediend', 'bedienden'],
#   'related_matches': {'aat': ['300025874'],
#    'wikidata': ['Q833860'],
#    'pwn': ['None'],
#    'odwn': ['bediende-n-2'],
#    'nmvw': ['None']}},
#  'l_158': {'literal_form': 'Berber',
#   'lang': 'nl',
#   'query_terms': ['berber', 'berbers'],
#   'related_matches': {'aat': ['300016593'],
#    'wikidata': ['Q45315'],
#    'pwn': ['None'],
#    'odwn': ['Berber-n-2'],
#    'nmvw': ['10078557']}},
#  'l_168': {'literal_form': 'Birma',
#   'lang': 'nl',
#   'query_terms': ['birma'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q836'],
#    'pwn': ['None'],
#    'odwn': ['Birma-n-1'],
#    'nmvw': ['10063469']}},
#  'l_161': {'literal_form': 'Blank',
#   'lang': 'nl',
#   'query_terms': ['blank',
#    'blankere',
#    'blanker',
#    'blanke',
#    'blanks',
#    'blankste',
#    'blankst',
#    'blanken'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q235155'],
#    'pwn': ['None'],
#    'odwn': ['blanke-n-1'],
#    'nmvw': ['None']}},
#  'l_163': {'literal_form': 'Bombay',
#   'lang': 'nl',
#   'query_terms': ['bombay'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1156'],
#    'pwn': ['None'],
#    'odwn': ['Bombay-n-1'],
#    'nmvw': ['10063974']}},
#  'l_173': {'literal_form': 'Boslandcreool',
#   'lang': 'nl',
#   'query_terms': ['boslandcreool', 'boslandcreolen'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q445485'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['10076611']}},
#  'l_170': {'literal_form': 'Bosneger',
#   'lang': 'nl',
#   'query_terms': ['bosneger', 'bosnegers'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q445485'],
#    'pwn': ['None'],
#    'odwn': ['bosneger-n-1'],
#    'nmvw': ['10076611']}},
#  'l_165': {'literal_form': 'Calcutta',
#   'lang': 'nl',
#   'query_terms': ['calcutta'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1348'],
#    'pwn': ['None'],
#    'odwn': ['Calcutta-n-1'],
#    'nmvw': ['10063844']}},
#  'l_174': {'literal_form': 'Derde Wereld',
#   'lang': 'nl',
#   'query_terms': ['derde wereld'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q180194'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_179': {'literal_form': 'Dwerg',
#   'lang': 'nl',
#   'query_terms': ['dwerg', 'dwergen'],
#   'related_matches': {'aat': ['300236748'],
#    'wikidata': ['Q2419953'],
#    'pwn': ['None'],
#    'odwn': ['dwerg-n-1'],
#    'nmvw': ['None']}},
#  'l_175': {'literal_form': 'Eerste Wereld',
#   'lang': 'nl',
#   'query_terms': ['eerste wereld'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q876830'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_185': {'literal_form': 'Eskimo',
#   'lang': 'nl',
#   'query_terms': ['eskimo', "eskimo's"],
#   'related_matches': {'aat': ['300017447'],
#    'wikidata': ['Q131242'],
#    'pwn': ['None'],
#    'odwn': ['Eskimo-n-1'],
#    'nmvw': ['10075943']}},
#  'l_193': {'literal_form': 'Etniciteit',
#   'lang': 'nl',
#   'query_terms': ['etniciteit', 'etniciteiten'],
#   'related_matches': {'aat': ['300250435'],
#    'wikidata': ['Q5404323'],
#    'pwn': ['None'],
#    'odwn': ['etniciteit-n-1'],
#    'nmvw': ['None']}},
#  'l_194': {'literal_form': 'etnische groep',
#   'lang': 'nl',
#   'query_terms': ['etnische groep', 'etnische groepen'],
#   'related_matches': {'aat': ['300191997'],
#    'wikidata': ['Q41710'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_196': {'literal_form': 'Exotisch',
#   'lang': 'nl',
#   'query_terms': ['exotisch', 'exotischere', 'exotischer', 'exotische'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_197': {'literal_form': 'Gay',
#   'lang': 'nl',
#   'query_terms': ['gay', 'gayer', 'gayst', 'gaye', 'gayste', 'gays'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q592'],
#    'pwn': ['None'],
#    'odwn': ['gay-n-1'],
#    'nmvw': ['None']}},
#  'l_211': {'literal_form': 'gehandicapten',
#   'lang': 'nl',
#   'query_terms': ['gehandicapte', 'gehandicapten'],
#   'related_matches': {'aat': ['300025921'],
#    'wikidata': ['Q15978181'],
#    'pwn': ['None'],
#    'odwn': ['gehandicapte-n-1'],
#    'nmvw': ['None']}},
#  'l_198': {'literal_form': 'Gekleurd',
#   'lang': 'nl',
#   'query_terms': ['gekleurd',
#    'gekleurdste',
#    'gekleurdst',
#    'gekleurds',
#    'gekleurde',
#    'gekleurdere',
#    'gekleurder'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q2072081'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_204': {'literal_form': 'Halfbloed',
#   'lang': 'nl',
#   'query_terms': ['halfbloed', 'halfbloeden'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['halfbloed-n-1'],
#    'nmvw': ['None']}},
#  'l_210': {'literal_form': 'Handicap',
#   'lang': 'nl',
#   'query_terms': ['handicap', 'handicaps'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q12131'],
#    'pwn': ['None'],
#    'odwn': ['handicap-n-1'],
#    'nmvw': ['None']}},
#  'l_213': {'literal_form': 'Hermafrodiet',
#   'lang': 'nl',
#   'query_terms': ['hermafrodiet', 'hermafrodieten'],
#   'related_matches': {'aat': ['300386060'],
#    'wikidata': ['Q303479'],
#    'pwn': ['None'],
#    'odwn': ['hermafrodiet-n-1'],
#    'nmvw': ['None']}},
#  'l_217': {'literal_form': 'Homo',
#   'lang': 'nl',
#   'query_terms': ['homo', "homo's"],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q104969456'],
#    'pwn': ['None'],
#    'odwn': ['homo-n-1'],
#    'nmvw': ['None']}},
#  'l_219': {'literal_form': 'Homoseksualiteit',
#   'lang': 'nl',
#   'query_terms': ['homoseksualiteit'],
#   'related_matches': {'aat': ['300055188'],
#    'wikidata': ['Q6636'],
#    'pwn': ['None'],
#    'odwn': ['homoseksualiteit-n-2', 'homoseksualiteit-n-3'],
#    'nmvw': ['None']}},
#  'l_218': {'literal_form': 'Homoseksueel',
#   'lang': 'nl',
#   'query_terms': ['homoseksueel',
#    'homoseksueler',
#    'homoseksueelste',
#    'homoseksuelere',
#    'homoseksueelst',
#    'homoseksueels',
#    'homoseksuelen',
#    'homoseksuele'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q592'],
#    'pwn': ['None'],
#    'odwn': ['homoseksueel-n-1'],
#    'nmvw': ['None']}},
#  'l_224': {'literal_form': 'Hottentot',
#   'lang': 'nl',
#   'query_terms': ['hottentot', 'hottentotten'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q219252'],
#    'pwn': ['None'],
#    'odwn': ['Hottentot-n-1'],
#    'nmvw': ['10078204']}},
#  'l_226': {'literal_form': 'Inboorling',
#   'lang': 'nl',
#   'query_terms': ['inboorling', 'inboorlingen'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['inboorling-n-1'],
#    'nmvw': ['None']}},
#  'l_228': {'literal_form': 'Indiaan',
#   'lang': 'nl',
#   'query_terms': ['indiaan', 'indianen', 'indiaans'],
#   'related_matches': {'aat': ['300017437'],
#    'wikidata': ['Q36747'],
#    'pwn': ['None'],
#    'odwn': ['Indiaan-n-1'],
#    'nmvw': ['None']}},
#  'l_229': {'literal_form': 'Indisch',
#   'lang': 'nl',
#   'query_terms': ['indisch', 'indischer', 'indische', 'indischere'],
#   'related_matches': {'aat': ['300418042'],
#    'wikidata': ['Q188161'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['10077429']}},
#  'l_230': {'literal_form': 'Indo',
#   'lang': 'nl',
#   'query_terms': ["indoindo's"],
#   'related_matches': {'aat': ['300386794'],
#    'wikidata': ['Q2116909'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_232': {'literal_form': 'Inheems',
#   'lang': 'nl',
#   'query_terms': ['inheems',
#    'inheemst',
#    'inheemse',
#    'inheemsere',
#    'inheemste',
#    'inheemser'],
#   'related_matches': {'aat': ['300379660'],
#    'wikidata': ['Q103817'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['10075993']}},
#  'l_227': {'literal_form': 'Inlander',
#   'lang': 'nl',
#   'query_terms': ['inlander', 'inlanders'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1945590'],
#    'pwn': ['None'],
#    'odwn': ['inlander-n-1'],
#    'nmvw': ['None']}},
#  'l_287': {'literal_form': 'Inuit',
#   'lang': 'nl',
#   'query_terms': ['inuk', 'inuit'],
#   'related_matches': {'aat': ['300017455'],
#    'wikidata': ['Q189975'],
#    'pwn': ['None'],
#    'odwn': ['Inuit-n-1'],
#    'nmvw': ['10075943']}},
#  'l_234': {'literal_form': 'Islamiet',
#   'lang': 'nl',
#   'query_terms': ['islamiet', 'islamieten'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q47740'],
#    'pwn': ['None'],
#    'odwn': ['islamiet-n-1'],
#    'nmvw': ['None']}},
#  'l_237': {'literal_form': 'Jap',
#   'lang': 'nl',
#   'query_terms': ['jap', 'jappen', 'japs'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1192767'],
#    'pwn': ['None'],
#    'odwn': ['Jap-n-1'],
#    'nmvw': ['None']}},
#  'l_238': {'literal_form': 'Jappenkamp',
#   'lang': 'nl',
#   'query_terms': ['jappenkamp', 'jappenkampen'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q2432369'],
#    'pwn': ['None'],
#    'odwn': ['jappenkamp-n-1'],
#    'nmvw': ['None']}},
#  'l_236': {'literal_form': 'Jappenkampen',
#   'lang': 'nl',
#   'query_terms': ['jappenkamp', 'jappenkampen'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q2432369'],
#    'pwn': ['None'],
#    'odwn': ['jappenkamp-n-1'],
#    'nmvw': ['None']}},
#  'l_244': {'literal_form': 'Kaffer',
#   'lang': 'nl',
#   'query_terms': ['kaffer', 'kaffers'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1285250'],
#    'pwn': ['None'],
#    'odwn': ['kaffer-n-2'],
#    'nmvw': ['None']}},
#  'l_245': {'literal_form': 'Kaukasisch',
#   'lang': 'nl',
#   'query_terms': ['kaukasisch',
#    'kaukasische',
#    'kaukasischere',
#    'kaukasischer'],
#   'related_matches': {'aat': ['300244536'],
#    'wikidata': ['Q7129609'],
#    'pwn': ['None'],
#    'odwn': ['Kaukasische-n-1'],
#    'nmvw': ['None']}},
#  'l_156': {'literal_form': 'knecht',
#   'lang': 'nl',
#   'query_terms': ['knecht', 'knechten', 'knechts'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['knecht-n-1'],
#    'nmvw': ['None']}},
#  'l_246': {'literal_form': 'Koelie',
#   'lang': 'nl',
#   'query_terms': ['koelie', 'koelies'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q548135'],
#    'pwn': ['None'],
#    'odwn': ['koelie-n-1', 'koelie-n-2'],
#    'nmvw': ['None']}},
#  'l_247': {'literal_form': 'Koppensneller',
#   'lang': 'nl',
#   'query_terms': ['koppensneller', 'koppensnellers'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['koppensneller-n-3'],
#    'nmvw': ['None']}},
#  'l_178': {'literal_form': 'lagelonenlanden',
#   'lang': 'nl',
#   'query_terms': ['lagelonenland', 'lagelonenlanden'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q2639564'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_180': {'literal_form': 'lilliputter',
#   'lang': 'nl',
#   'query_terms': ['lilliputter', 'lilliputters'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q2419953'],
#    'pwn': ['None'],
#    'odwn': ['lilliputter-n-1'],
#    'nmvw': ['None']}},
#  'l_166': {'literal_form': 'Madras',
#   'lang': 'nl',
#   'query_terms': ['madras'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1352'],
#    'pwn': ['None'],
#    'odwn': ['Madras-n-1'],
#    'nmvw': ['10063793']}},
#  'l_172': {'literal_form': 'Marron',
#   'lang': 'nl',
#   'query_terms': ['marron', 'marrons'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q445485'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['10076611']}},
#  'l_253': {'literal_form': 'Medicijnman',
#   'lang': 'nl',
#   'query_terms': ['medicijnman', 'medicijnmannen'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q42042'],
#    'pwn': ['None'],
#    'odwn': ['medicijnman-n-1'],
#    'nmvw': ['None']}},
#  'l_209': {'literal_form': 'mesties',
#   'lang': 'nl',
#   'query_terms': ['mesties', 'mestiezen'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q106713'],
#    'pwn': ['None'],
#    'odwn': ['mesties-n-1'],
#    'nmvw': ['None']}},
#  'l_288': {'literal_form': 'Métis',
#   'lang': 'nl',
#   'query_terms': ['métis', 'metis'],
#   'related_matches': {'aat': ['300265512'],
#    'wikidata': ['Q262457'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_256': {'literal_form': 'Mohammedaan',
#   'lang': 'nl',
#   'query_terms': ['mohammedaan', 'mohammedanen'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q47740'],
#    'pwn': ['None'],
#    'odwn': ['mohammedaan-n-1'],
#    'nmvw': ['None']}},
#  'l_258': {'literal_form': 'Mongool',
#   'lang': 'nl',
#   'query_terms': ['mongool', 'mongolen', 'mongools'],
#   'related_matches': {'aat': ['300387497'],
#    'wikidata': ['Q207912'],
#    'pwn': ['None'],
#    'odwn': ['mongool-n-1', 'mongool-n-2'],
#    'nmvw': ['None']}},
#  'l_261': {'literal_form': 'Moor',
#   'lang': 'nl',
#   'query_terms': ['moor', 'moren', 'moors'],
#   'related_matches': {'aat': ['300021016'],
#    'wikidata': ['Q169260'],
#    'pwn': ['None'],
#    'odwn': ['moor-n-1', 'Moor-n-2'],
#    'nmvw': ['10078542']}},
#  'l_208': {'literal_form': 'Mulat',
#   'lang': 'nl',
#   'query_terms': ['mulat', 'mulatten'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q191923'],
#    'pwn': ['None'],
#    'odwn': ['mulat-n-1'],
#    'nmvw': ['None']}},
#  'l_171': {'literal_form': 'Neger',
#   'lang': 'nl',
#   'query_terms': ['neger', 'negers'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q1130557'],
#    'pwn': ['None'],
#    'odwn': ['neger-n-1'],
#    'nmvw': ['None']}},
#  'l_262': {'literal_form': 'Ontdekken',
#   'lang': 'nl',
#   'query_terms': ['ontdekken'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['ontdekken-v-4'],
#    'nmvw': ['None']}},
#  'l_177': {'literal_form': 'ontwikkelingslanden',
#   'lang': 'nl',
#   'query_terms': ['ontwikkelingsland', 'ontwikkelingslanden'],
#   'related_matches': {'aat': ['300379994'],
#    'wikidata': ['Q177323'],
#    'pwn': ['None'],
#    'odwn': ['ontwikkelingsland-n-1'],
#    'nmvw': ['None']}},
#  'l_263': {'literal_form': 'Oriëntaals',
#   'lang': 'nl',
#   'query_terms': ['oriëntaals',
#    'oriëntaalste',
#    'oriëntaalsere',
#    'oriëntaal',
#    'oriëntale',
#    'oriëntalere',
#    'oriëntaalse',
#    'oriëntaalst',
#    'oriëntaler',
#    'oriëntaalser'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_155': {'literal_form': 'page',
#   'lang': 'nl',
#   'query_terms': ['page', 'pages'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q855855'],
#    'pwn': ['None'],
#    'odwn': ['page-n-1'],
#    'nmvw': ['None']}},
#  'l_265': {'literal_form': 'Politionele actie',
#   'lang': 'nl',
#   'query_terms': ['politionele actie', 'politionele acties'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q278039'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_267': {'literal_form': 'Primitief',
#   'lang': 'nl',
#   'query_terms': ['primitief',
#    'primitiefst',
#    'primitievere',
#    'primitiefste',
#    'primitiefs',
#    'primitieve',
#    'primitiever'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['primitief-n-1'],
#    'nmvw': ['None']}},
#  'l_268': {'literal_form': 'Primitivisme',
#   'lang': 'nl',
#   'query_terms': ['primitivisme', 'primitivismen'],
#   'related_matches': {'aat': ['300056548'],
#    'wikidata': ['Q848365'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_269': {'literal_form': 'Pygmee',
#   'lang': 'nl',
#   'query_terms': ['pygmee', 'pygmeeën'],
#   'related_matches': {'aat': ['300016430'],
#    'wikidata': ['Q171927'],
#    'pwn': ['None'],
#    'odwn': ['pygmee-n-1'],
#    'nmvw': ['10078766']}},
#  'l_270': {'literal_form': 'Queer',
#   'lang': 'nl',
#   'query_terms': ['queer'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q51415'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_195': {'literal_form': 'Ras',
#   'lang': 'nl',
#   'query_terms': ['ras',
#    'rasser',
#    'raste',
#    'rasse',
#    'rassere',
#    'rast',
#    'rassen'],
#   'related_matches': {'aat': ['300256475'],
#    'wikidata': ['Q3254959'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_272': {'literal_form': 'Roots',
#   'lang': 'nl',
#   'query_terms': ['roots'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_273': {'literal_form': 'Slaaf',
#   'lang': 'nl',
#   'query_terms': ['slaaf', 'slaven'],
#   'related_matches': {'aat': ['300230899'],
#    'wikidata': ['Q12773225'],
#    'pwn': ['None'],
#    'odwn': ['slaaf-n-1'],
#    'nmvw': ['20404']}},
#  'l_276': {'literal_form': 'Stam',
#   'lang': 'nl',
#   'query_terms': ['stam', 'stammen'],
#   'related_matches': {'aat': ['300049946'],
#    'wikidata': ['Q133311'],
#    'pwn': ['None'],
#    'odwn': ['stam-n-2'],
#    'nmvw': ['None']}},
#  'l_277': {'literal_form': 'Traditioneel',
#   'lang': 'nl',
#   'query_terms': ['traditioneel',
#    'traditioneels',
#    'traditionele',
#    'traditioneelste',
#    'traditioneelst',
#    'traditionelere',
#    'traditioneler'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_279': {'literal_form': 'Trans',
#   'lang': 'nl',
#   'query_terms': ['trans', 'transen'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['trans-n-3'],
#    'nmvw': ['None']}},
#  'l_280': {'literal_form': 'travestiet',
#   'lang': 'nl',
#   'query_terms': ['travestiet', 'travestieten'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q486680'],
#    'pwn': ['None'],
#    'odwn': ['travestiet-n-1'],
#    'nmvw': ['None']}},
#  'l_176': {'literal_form': 'Tweede Wereld',
#   'lang': 'nl',
#   'query_terms': ['tweede wereld'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q233472'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_207': {'literal_form': 'volbloed',
#   'lang': 'nl',
#   'query_terms': ['volbloed', 'volbloeden'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['None'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_282': {'literal_form': 'Westers',
#   'lang': 'nl',
#   'query_terms': ['westers',
#    'wester',
#    'westerse',
#    'westersere',
#    'westerste',
#    'westerst',
#    'westerser'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q160381'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_200': {'literal_form': 'Wit',
#   'lang': 'nl',
#   'query_terms': ['wit',
#    'witten',
#    'wittere',
#    'witst',
#    'witte',
#    'witter',
#    'wits',
#    'witste'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q235155'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_283': {'literal_form': 'Zigeuner',
#   'lang': 'nl',
#   'query_terms': ['zigeuner', 'zigeuners'],
#   'related_matches': {'aat': ['300404070'],
#    'wikidata': ['Q76475'],
#    'pwn': ['None'],
#    'odwn': ['zigeuner-n-1'],
#    'nmvw': ['10075876']}},
#  'l_169': {'literal_form': 'Zuid\xad-Rhodesië',
#   'lang': 'nl',
#   'query_terms': ['zuid-rhodesië'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q750583'],
#    'pwn': ['None'],
#    'odwn': ['None'],
#    'nmvw': ['None']}},
#  'l_199': {'literal_form': 'Zwart',
#   'lang': 'nl',
#   'query_terms': ['zwart',
#    'zwarten',
#    'zwartst',
#    'zwarter',
#    'zwarts',
#    'zwarte',
#    'zwartere',
#    'zwartste'],
#   'related_matches': {'aat': ['None'],
#    'wikidata': ['Q817393'],
#    'pwn': ['None'],
#    'odwn': ['zwarte-n-1', 'zwarte-n-3'],
#    'nmvw': ['None']}}}

# %%
# saving realted matches as json
with open('related_matches.json', 'w') as jf:
    json.dump(related_matches_dict, jf)

# %% [markdown]
# ### Merging related matches with literals

# %% [markdown]
# #### Importing literals from the json files
#  the files were generated with lodlitparser.get_literals()

# %%
# AAT EN
path_aat_en = 'https://github.com/cultural-ai/wordsmatter/raw/main/rm.json'
related_matches = requests.get(path_to_rm).json()

with open('/Users/anesterov/reps/LODlit/aat_rm_en.json','r') as jf:
    aat_en = json.load(jf)
# AAT NL
with open('/Users/anesterov/reps/LODlit/aat_rm_nl.json','r') as jf:
    aat_nl = json.load(jf)
# Wikidata EN
with open('/Users/anesterov/reps/LODlit/wikidata_rm_en.json','r') as jf:
    wikidata_en = json.load(jf)
# Wikidata NL
with open('/Users/anesterov/reps/LODlit/wikidata_rm_nl.json','r') as jf:
    wikidata_nl = json.load(jf)
# PWN
with open('/Users/anesterov/reps/LODlit/pwn_rm.json','r') as jf:
    pwn_rm = json.load(jf)
# ODWN
with open('/Users/anesterov/reps/LODlit/odwn_rm.json','r') as jf:
    odwn_rm = json.load(jf)
# NMVW
with open('/Users/anesterov/reps/LODlit/nmvw_rm.json','r') as jf:
    nmvw_rm = json.load(jf)

# %%
# this code updates related_matches_dict
for label_uri, values in related_matches_dict.items():
    
    literals_per_label = {}
    
    # EN
    if values['lang'] == 'en':
        # aat
        per_resource =[]
        if values['related_matches']['aat'][0] != 'None':
            aat_uri = values['related_matches']['aat'][0]
            aat_en[aat_uri]['aat_uri'] = aat_uri
            per_resource.append(aat_en[aat_uri])

        literals_per_label['aat_en'] = per_resource
        
        # wikidata
        per_resource =[]
        if values['related_matches']['wikidata'][0] != 'None':
            wikidata_q = values['related_matches']['wikidata'][0]
            for result in wikidata_en:
                if wikidata_q in result.keys():
                    per_resource.append(result[wikidata_q])

        literals_per_label['wikidata_en'] = per_resource
        
        # PWN
        per_resource = []
        for synset_id in values['related_matches']['pwn']:
            if synset_id != 'None':
                pwn_rm[synset_id]['synset_id'] = synset_id
                dict_per_hit = pwn_rm[synset_id]
                per_resource.append(dict_per_hit)
            
        literals_per_label['pwn'] = per_resource
        
    # NL
    if values['lang'] == 'nl':
        # aat
        per_resource = []
        if values['related_matches']['aat'][0] != 'None':
            aat_uri = values['related_matches']['aat'][0]
            aat_nl[aat_uri]['aat_uri'] = aat_uri
            per_resource.append(aat_nl[aat_uri])

        literals_per_label['aat_nl'] = per_resource
        
        #odwn
        per_resource = []
        for le_id in values['related_matches']['odwn']:
            if le_id != 'None':
                odwn_rm[le_id]['LE_id'] = le_id
                dict_per_hit = odwn_rm[le_id]
                per_resource.append(dict_per_hit)
                
        literals_per_label['odwn'] = per_resource
        
        #nmvw
        per_resource = []
        if values['related_matches']['nmvw'][0] != 'None':
            nmvw_handle = f"https://hdl.handle.net/20.500.11840/termmaster{values['related_matches']['nmvw'][0]}"
            nmvw_rm[nmvw_handle]['nmvw_handle'] = nmvw_handle
            per_resource.append(nmvw_rm[nmvw_handle])
        
        literals_per_label['nmvw'] = per_resource
        
    values['related_matches_literals'] = literals_per_label

# %%
with open('rm_literals.json', 'w') as jf:
    json.dump(related_matches_dict, jf)

# %%
aat_en
# Out:
# {'300379660': {'lang': 'en',
#   'prefLabel': 'indigenous people',
#   'altLabels': ['indigenous person',
#    'indigenous peoples',
#    'aboriginal peoples',
#    'indigenous populations',
#    'native peoples',
#    'aborigines',
#    'indigenes',
#    'people, indigenous'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'The original, or earliest known, inhabitants of a colony or country.',
#   'aat_uri': '300379660'},
#  '300016593': {'lang': 'en',
#   'prefLabel': 'Berber (culture or style)',
#   'altLabels': ['Berbers (cultures or styles)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': None,
#   'aat_uri': '300016593'},
#  '300435249': {'lang': 'en',
#   'prefLabel': 'Black (general, race and ethnicity)',
#   'altLabels': [''],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'General designation for the race, ethnicity, styles, culture, and heritage of people of sub-Saharan African origin or descent in places outside Africa, or of members of any dark-skinned group of peoples, including those of  Australian Aboriginal origin or descent.',
#   'aat_uri': '300435249'},
#  '300244536': {'lang': 'en',
#   'prefLabel': 'Caucasian (culture or style)',
#   'altLabels': [''],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': "Refers to the people, styles, and cultures originating in the general Caucasus region, which is the area between the Black and Caspian Seas, surrounding the Caucasus mountains, comprising roughly the modern nations of Georgia, Armenia, Azerbaijan, southern parts of Russia, and northeastern Turkey. It refers specifically to the Indo-European and Turkic cultures that have occupied the area since around the first millennium BCE. It takes its name from the Caucasus tribes that settled here; was home to Milesian Greeks, subsequently was invaded numerous times; legendary site of Jason's quest for Golden Fleece; the Caucasus mountains have traditionally been the boundary separating Europe from Asia; however, the area is more subject to Asian influence and so is more often grouped with Asia in modern scholarship.",
#   'aat_uri': '300244536'},
#  '300379994': {'lang': 'en',
#   'prefLabel': 'developing countries',
#   'altLabels': ['developing country',
#    'Third World',
#    'emerging nations',
#    'developing nations',
#    'least-developed countries',
#    'less-developed countries',
#    'LDCs',
#    'countries, developing'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Refers to countries with low per capita income and an undeveloped industrial base relative to other countries.',
#   'aat_uri': '300379994'},
#  '300025921': {'lang': 'en',
#   'prefLabel': 'handicapped',
#   'altLabels': ["handicapped's", 'disabled', 'disabled people'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Those burdened with an encumbrance or disadvantage, physical or mental, that may hinder their ability to cope with the demands of daily life.',
#   'aat_uri': '300025921'},
#  '300236748': {'lang': 'en',
#   'prefLabel': 'dwarfs',
#   'altLabels': ['dwarf', "dwarf's", "dwarfs'", 'dwarves'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'People who are abnormally small in stature.',
#   'aat_uri': '300236748'},
#  '300017447': {'lang': 'en',
#   'prefLabel': 'Eskimo (culture or style)',
#   'altLabels': ['Eskimo Tradition'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Refers to artwork produced by native Arctic culture, prior to European contact. For names of specific native peoples of the present, use descriptors such as "Chugach," "Inuit," or "Katladlit."',
#   'aat_uri': '300017447'},
#  '300191997': {'lang': 'en',
#   'prefLabel': 'ethnic groups',
#   'altLabels': ['ethnic group', 'groups, ethnic'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Subgroups within a larger cultural or social order that are distinguished from the majority and each other by their national, religious, linguistic, cultural, or sometimes racial background. For groups that are the objects of prejudice or discrimination from the majority, use "minorities."',
#   'aat_uri': '300191997'},
#  '300250435': {'lang': 'en',
#   'prefLabel': 'ethnicity',
#   'altLabels': ['ethnic', 'ethnic group identity', 'ethnic identity'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'The perception of identity, distinctiveness, and significance of a group that shares a linguistic group, religious belief, nationality, cultural tradition, or perceived physiological characteristics.',
#   'aat_uri': '300250435'},
#  '300449024': {'lang': 'en',
#   'prefLabel': 'developed countries',
#   'altLabels': ['developed country', 'developed world', 'First World'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Describes nations of the world that are considered economically and technologically advanced. Generally consider this more current and accurate than "First World."',
#   'aat_uri': '300449024'},
#  '300055188': {'lang': 'en',
#   'prefLabel': 'homosexuality',
#   'altLabels': ['homosexual (sexuality)',
#    'gay (general homosexuality)',
#    'queer (homosexual)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': "Sexuality characterized by romantic love or sexual desire toward members of one's own sex.",
#   'aat_uri': '300055188'},
#  '300404070': {'lang': 'en',
#   'prefLabel': 'Rom (culture)',
#   'altLabels': ['Roma (culture)', 'Gypsy', 'Gipsy'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'The culture and ethnic group of the traditionally itinerant people who originated in northern India but live in modern times worldwide, principally in Europe. Most Roma speak some form of Romani a language closely related to the modern Indo-European languages of northern India, as well as the major language of the country in which they live. It is generally agreed that Roma groups left India in repeated migrations and that they were in Persia by the 11th century, in southeastern Europe by the beginning of the 14th, and in western Europe by the 15th century. By the second half of the 20th century they had spread to every inhabited continent.',
#   'aat_uri': '300404070'},
#  '300386060': {'lang': 'en',
#   'prefLabel': 'hermaphrodites (people)',
#   'altLabels': ['intersex people',
#    'intersexuals',
#    'intersexual (people)',
#    'hermaphrodite (person)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': "People that are born with both male and female sex organs. Historically the term 'hermaphrodite' has been used in this context, but now prefer 'intersex people'. Reserve use of the term 'hermaphrodite' for the context of organisms that can produce both gametes associated with male and female sexes.",
#   'aat_uri': '300386060'},
#  '300435115': {'lang': 'en',
#   'prefLabel': 'homosexuals (people)',
#   'altLabels': ['homosexual (person)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'People having sexual attraction or sexual relations with others of the same sex.',
#   'aat_uri': '300435115'},
#  '300016575': {'lang': 'en',
#   'prefLabel': 'Khoikhoi',
#   'altLabels': ['Hottentot'],
#   'prefLabel_comment': 'meaning "men of men"',
#   'altLabel_comment': 'now considered pejorative, used after 1652/mid-20th century; probably invented by the Dutch colonists in imitation of the clicking sounds of their language',
#   'scopeNote': 'Refers to the people and culture of southern Africa whom the first European explorers found in areas of the hinterland and who now live either in European settlements or on official reserves in South Africa or Namibia. Most Khoikhoi are either Nama or Oorlams, the latter term denoting remnants of the "Cape Hottentots" together with many of hybrid descent. The main Nama concentrations are the Bondelswarts, Rooinasie, Swartboois, and Topnaars; the main Orlams groups are the Witbooi, Amraal, Berseba, and Bethanie. The Khoikhoi are not easily distinguishable physically from the San, the Khoikhoi\'s slightly taller stature and decidedly longer and narrower head being the only marked differences.',
#   'aat_uri': '300016575'},
#  '300025844': {'lang': 'en',
#   'prefLabel': 'immigrants',
#   'altLabels': ['immigrant', "immigrant's", "immigrants'"],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'People who enter a country or region from another to settle there. For those who depart from their native or usual country or region to live elsewhere, use "emigrants."',
#   'aat_uri': '300025844'},
#  '300017437': {'lang': 'en',
#   'prefLabel': 'Native American',
#   'altLabels': ['American Indian',
#    'Indigenous American',
#    'Indian (Native American)',
#    'Native (Native American)',
#    'American, Native',
#    'Indian, American',
#    'Native Americans'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Whenever possible, use the specific tribal name. The general term "Native American" is widely used in the United States, but many groups now prefer "American Indian" or "Indigenous American." This concept is typically reserved to refer narrowly to the cultures of the native peoples of the United States and Canada, excluding the Eskimos and Aleuts. For the indigenous peoples of Canada use the term "First Nations." For the broader concept of the cultures of any native peoples of Central America, South America, North America, or the West Indies who are considered to belong to the Mongoloid division of the human species, use "Amerindian (culture)."',
#   'aat_uri': '300017437'},
#  '300386794': {'lang': 'en',
#   'prefLabel': 'Indo-European (culture)',
#   'altLabels': ['Japhetic'],
#   'prefLabel_comment': None,
#   'altLabel_comment': 'Japheth, one of the sons of the Biblical Noah',
#   'scopeNote': 'Ancient cultures of the peoples associated with broad class of cognate languages that are still spoken over the greater part of Europe and extending into Asia as far as northern India. Included are the cultures associated with the existing and extinct language families of Anatolian, Hellenic, Indo-Iranian, Italic, Celtic, Germanic, Tocharian, Balto-Slavic, Armenian, Albanian, Illyrian, Venetic, Liburnian, Messapian, Phrygian, Paionian, Thracian, Ancient Macedonian, Ligurian, Sicel, and Lusitanian, among others.',
#   'aat_uri': '300386794'},
#  '300017455': {'lang': 'en',
#   'prefLabel': 'Inuit (Canadian Arctic Native style)',
#   'altLabels': ['Canadian Eskimo', 'Eskimo, Canadian'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': None,
#   'aat_uri': '300017455'},
#  '300443390': {'lang': 'en',
#   'prefLabel': 'Maroon',
#   'altLabels': ['maroon'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Style and culture of a community or group of formerly enslaved Africans and Amerindian peoples and their descendants who fled, resisted, or rebelled against enslavement and found freedom in remote regions near where they had been forcibly relocated. Many of these groups have survived in the Caribbean and the Americas. Note that this community of people did not originally refer to themselves as “Maroon,” though some of their contemporary descendants have adopted the term, while others may consider it pejorative.',
#   'aat_uri': '300443390'},
#  '300218522': {'lang': 'en',
#   'prefLabel': 'shamans',
#   'altLabels': ['shaman',
#    "shamans'",
#    "shaman's",
#    'medicine men',
#    'medicine women',
#    'men, medicine',
#    'women, medicine'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Those who act as intermediaries between the natural and supernatural worlds, serving as healers and priests, foretelling the future, and controlling spiritual forces for the welfare of the community.',
#   'aat_uri': '300218522'},
#  '300265512': {'lang': 'en',
#   'prefLabel': 'Metis',
#   'altLabels': ['Métis'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Refers to the culture of the Metis, peoples of mixed French-Canadian and Native American ancestry.',
#   'aat_uri': '300265512'},
#  '300073715': {'lang': 'en',
#   'prefLabel': 'Islam',
#   'altLabels': ['Islamic (religion)',
#    'Islamism',
#    'Mohammedan',
#    'Mohammedanism',
#    'Moslem',
#    'Muhammadanism',
#    'Muslim',
#    'Muslimism',
#    'Mussulmanism',
#    'mahométanisme',
#    'islamisme'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': "Refers to the religious beliefs and social practices founded in the seventh century by the Arabian Prophet Muhammad, held to be the last of a series of major prophets, which include, according to Islamic dogma, Adam, Noah, and Jesus. It later spread throughout the Middle East, Africa, Europe, and parts of Asia. It is characterized by the belief in the fundamental idea that a devotee 'surrenders' and submits his will to Allah, the prime creator and sustainer of the universe and all creation. In Islam, God is unique and has no partner or intermediary as in the Christian Trinity. Social service and the active alleviation of suffering in others is considered the only path to salvation and prayer and sacred ritual alone are inadequate forms of submission to Allah. The Qur'an (Koran), the sacred text of the religion, is a compilation of revelations from Allah believed to have been received by Muhammad.",
#   'aat_uri': '300073715'},
#  '300375152': {'lang': 'en',
#   'prefLabel': 'Maure',
#   'altLabels': ['Maures',
#    'Moor (culture or style)',
#    'Mauri (Arab-Berber culture or style)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Style and culture of a people of mixed Arab-Berber descent inhabiting the Western Sahara, neighboring parts of Morocco, Mali, Algeria, and the Islamic Republic of Mauritania. To refer to the products, style and culture of people living within the boundaries of Mauritania proper use "Mauritanian."',
#   'aat_uri': '300375152'},
#  '300018125': {'lang': 'en',
#   'prefLabel': 'African American',
#   'altLabels': ['Afro-American',
#    'Black (African American)',
#    'Negro (African American)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Designates the styles, culture, and heritage of  Americans of African descent in North America. The styles capture the essence of the African American experience and how personal and political rebellion and triumphs over prejudice and social adversity have enriched and contributed to the music, art, and literature of American culture as a whole.',
#   'aat_uri': '300018125'},
#  '300018279': {'lang': 'en',
#   'prefLabel': 'Asian',
#   'altLabels': ['Oriental (Asian)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Refers to the cultures of the continent of Asia, which is in the eastern hemisphere, and is bounded by the Pacific Ocean, the Indian Ocean, the Arctic Ocean, and is generally considered to be delimited on the west by the Ural Mountains. It also refers to the numerous islands off the coast of Asia.',
#   'aat_uri': '300018279'},
#  '300056500': {'lang': 'en',
#   'prefLabel': 'primitive art',
#   'altLabels': ['art, primitive'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'An outdated designation formerly used for the art of certain people considered to be outside the spheres of influence of other, politically dominant cultural groups; was used especially concerning communities in sub-Saharan Africa, the Pacific Islands, and native tribal groups throughout the Americas. Use instead "indigenous art," "tribal art," or the most specific name known for the culture of origin. Distinct from "primitivism," a term sometimes used for artistic styles or movements intended, often romantically or sentimentally, to emulate the appearance of art made by people operating outside of mainstream art markets.',
#   'aat_uri': '300056500'},
#  '300056548': {'lang': 'en',
#   'prefLabel': 'primitivism (artistic concept)',
#   'altLabels': ['neoprimitivism', 'neo-primitivism'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'A term sometimes used for artistic styles or movements intended, often romantically or sentimentally, to emulate the appearance of art that was formerly designated primitive and other art made by people operating outside of mainstream art markets. Distinct from "primitive art" and "primitive architecture," which are outdated terms formerly used for art and architecture of certain people considered to be outside the spheres of influence of other, politically dominant cultural groups. For the Russian art movement, active from about 1905 to 1920, which combined influences from Russian folk art with ideas borrowed from Cubism and Futurism, use "Primitivist."',
#   'aat_uri': '300056548'},
#  '300016430': {'lang': 'en',
#   'prefLabel': 'Pygmy (African culture or style)',
#   'altLabels': ['Pigmy (African culture or style)',
#    'Bakola (Pygmy, culture or style)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'The collective style and culture of various African peoples whose adult males grow to less than 59 inches (150 cm) in average height, and who live in Cameroon, Equatorial Guinea, Gabon, Democratic Republic of Congo, Congo Republic, Central African Republic, Rwanda, and Burundi. Use of "Pygmy" for a culture is considered pejorative; where possible use instead the most specific name for the subgroup.',
#   'aat_uri': '300016430'},
#  '300256475': {'lang': 'en',
#   'prefLabel': 'race (group of people)',
#   'altLabels': ['races (groups of people)', 'peoples (races)'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Identification of a group of people as distinct from other groups on the basis of physical or socially defined characteristics, such as the color of skin or language.',
#   'aat_uri': '300256475'},
#  '300025925': {'lang': 'en',
#   'prefLabel': 'intellectually disabled',
#   'altLabels': ['mentally retarded'],
#   'prefLabel_comment': None,
#   'altLabel_comment': 'term is considered offensive',
#   'scopeNote': 'People having any of several conditions characterized by subnormal intellectual functioning and impaired adaptive behavior that are identified during the individual’s developmental years.',
#   'aat_uri': '300025925'},
#  '300025874': {'lang': 'en',
#   'prefLabel': 'servants',
#   'altLabels': ['servant', "servant's", "servants'"],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Generally in historical usage, for people who are privately employed to perform personal or household services.',
#   'aat_uri': '300025874'},
#  '300230899': {'lang': 'en',
#   'prefLabel': 'enslaved people',
#   'altLabels': ['enslaved person',
#    'enslaved persons',
#    'slaves (people)',
#    'slave (person)',
#    "slave's (person's )",
#    "slaves' (peoples')",
#    'people, enslaved'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Those who are treated as the property of and are entirely subject to another person, whether by capture, purchase, or birth.',
#   'aat_uri': '300230899'},
#  '300435679': {'lang': 'en',
#   'prefLabel': 'traditional cultural properties',
#   'altLabels': ['traditional cultural property',
#    'traditional cultural places',
#    'TCP'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': "In the US, sites that are eligible for inclusion in the National Register because of their association with cultural practices or beliefs of a living community that are rooted in that community's history, and are important in maintaining the continuing cultural identity of the community.",
#   'aat_uri': '300435679'},
#  '300400510': {'lang': 'en',
#   'prefLabel': 'LGBTQ+',
#   'altLabels': ['LGBT',
#    'lesbian, gay, bisexual, and transgender',
#    'lesbian, gay, bisexual, transgender/transsexual/transvestite',
#    'L.G.B.T.Q.',
#    'LGB',
#    'GLBT',
#    'LGBTQ'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'General term for lesbian, gay, bisexual, or transgender / transsexual / transvestite attractions or behavior.',
#   'aat_uri': '300400510'},
#  '300049946': {'lang': 'en',
#   'prefLabel': 'tribes (kinship groups)',
#   'altLabels': ['tribe (kinship group)', 'tribal societies'],
#   'prefLabel_comment': None,
#   'altLabel_comment': None,
#   'scopeNote': 'Social, cultural groups, the members of which are held to be descended from a common ancestor, composed of numerous families, clans, or villages. They typically occupy a specific geographic territory, possess cultural, religious, and linguistic homogeneity, and are united politically under one head or chief.',
#   'aat_uri': '300049946'}}
